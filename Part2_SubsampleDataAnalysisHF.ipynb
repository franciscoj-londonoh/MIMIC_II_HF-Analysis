# %% [markdown]
# # 2. Subsample Data Analysis

# %%
# Import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import psycopg2
import getpass
# %matplotlib inline
plt.style.use('ggplot')

from sklearn.model_selection import train_test_split

# %%
# Database connection: information related to the previously created database
sqluser = 'postgres'
host = 'localhost'
dbname = 'mimic'
schema_name = 'mimiciii'

# Connect to postgres with a copy of the MIMIC-III database 
con = psycopg2.connect(dbname=dbname, user=sqluser, host=host, 
                      password=getpass.getpass(prompt='Password:'.format(sqluser)))

# State to the adequate Schema
cur = con.cursor()
cur.execute('SET search_path to {}'.format(schema_name))
# Out:
# Password:········

# %% [markdown]
# ## Physiological Measurements and Lab Exams Data

# %% [markdown]
# ### Hemodynamics data
# Hemodynamic measurements are fundamental in terms of Heart Failure diagnosis and subtype determination. However, the main reference values are extracted from medical imaging, which are not available in this case. Thus, a first approach is to use the available hemodynamic data to model patient conditions with commonly used physiological measurements at the ICU.

# %% [markdown]
# #### Systolic Heart Failure - Subsample Population
# A subsample population of patients with Systolic Heart Failure is selected, and hemodynamic measurements are analyzed to obtain a DataFrame to model the data.

# %%
query = \
"""
SELECT *
FROM chartevents c
INNER JOIN diagnoses_icd d ON c.subject_id = d.subject_id
INNER JOIN d_items d_i ON c.itemid = d_i.itemid
WHERE d.icd9_code = '42820' AND d_i.category = 'Hemodynamics'
"""
df_hf_sys_hemo = pd.read_sql_query(query, con)
df_hf_sys_hemo
# Out:
#           row_id  subject_id  hadm_id  icustay_id  itemid           charttime  \
# 0         181442        1767   147191      226932  220059 2168-04-14 21:00:00
# 1         181443        1767   147191      226932  220060 2168-04-14 21:00:00
# 2         181444        1767   147191      226932  220061 2168-04-14 21:00:00
# 3         181445        1767   147191      226932  220074 2168-04-14 21:00:00
# 4         181456        1767   147191      226932  220059 2168-04-14 22:00:00
# ...          ...         ...      ...         ...     ...                 ...
# 11692  321247185       90680   193278      286464  227805 2180-08-29 22:00:00
# 11693  321247196       90680   193278      286464  227805 2180-08-29 23:00:00
# 11694  321247286       90680   193278      286464  227805 2180-08-30 01:00:00
# 11695  322343999       91603   170884      262288  227805 2195-10-13 20:10:00
# 11696  322345665       91603   170884      262288  227805 2195-10-15 12:05:00
#
#                 storetime   cgid value  valuenum  ... row_id  itemid  \
# 0     2168-04-14 22:21:00  19786    32      32.0  ...  12721  220059
# 1     2168-04-14 22:21:00  19786    12      12.0  ...  12722  220060
# 2     2168-04-14 22:21:00  19786    21      21.0  ...  12723  220061
# 3     2168-04-14 22:21:00  19786     5       5.0  ...  12729  220074
# 4     2168-04-15 00:18:00  19786    34      34.0  ...  12721  220059
# ...                   ...    ...   ...       ...  ...    ...     ...
# 11692 2180-08-29 22:11:00  17950     4       NaN  ...  14927  227805
# 11693 2180-08-30 02:34:00  17950     2       NaN  ...  14927  227805
# 11694 2180-08-30 02:34:00  17950     4       NaN  ...  14927  227805
# 11695 2195-10-13 20:10:00  14891     1       NaN  ...  14927  227805
# 11696 2195-10-15 12:05:00  15039     1       NaN  ...  14927  227805
#
#                                      label abbreviation    dbsource  \
# 0       Pulmonary Artery Pressure systolic         PAPs  metavision
# 1      Pulmonary Artery Pressure diastolic         PAPd  metavision
# 2           Pulmonary Artery Pressure mean         PAPm  metavision
# 3                  Central Venous Pressure          CVP  metavision
# 4       Pulmonary Artery Pressure systolic         PAPs  metavision
# ...                                    ...          ...         ...
# 11692                             SvO2 SQI     SvO2 SQI  metavision
# 11693                             SvO2 SQI     SvO2 SQI  metavision
# 11694                             SvO2 SQI     SvO2 SQI  metavision
# 11695                             SvO2 SQI     SvO2 SQI  metavision
# 11696                             SvO2 SQI     SvO2 SQI  metavision
#
#            linksto      category  unitname  param_type conceptid
# 0      chartevents  Hemodynamics      mmHg     Numeric      None
# 1      chartevents  Hemodynamics      mmHg     Numeric      None
# 2      chartevents  Hemodynamics      mmHg     Numeric      None
# 3      chartevents  Hemodynamics      mmHg     Numeric      None
# 4      chartevents  Hemodynamics      mmHg     Numeric      None
# ...            ...           ...       ...         ...       ...
# 11692  chartevents  Hemodynamics      None        Text      None
# 11693  chartevents  Hemodynamics      None        Text      None
# 11694  chartevents  Hemodynamics      None        Text      None
# 11695  chartevents  Hemodynamics      None        Text      None
# 11696  chartevents  Hemodynamics      None        Text      None
#
# [11697 rows x 30 columns]

# %%
# Remove all data that parameter type is 'Text'
df_hf_s_ = df_hf_sys_hemo.T.drop_duplicates().T
df_hf_s_ = df_hf_s_[df_hf_s_['param_type'] != 'Text']
df_hf_s_
# Out:
#          row_id subject_id hadm_id icustay_id  itemid           charttime  \
# 0        181442       1767  147191     226932  220059 2168-04-14 21:00:00
# 1        181443       1767  147191     226932  220060 2168-04-14 21:00:00
# 2        181444       1767  147191     226932  220061 2168-04-14 21:00:00
# 3        181445       1767  147191     226932  220074 2168-04-14 21:00:00
# 4        181456       1767  147191     226932  220059 2168-04-14 22:00:00
# ...         ...        ...     ...        ...     ...                 ...
# 11658  18181260      63944  187913     249395  227547 2121-07-24 08:00:00
# 11659  18180678      63944  187913     249395  227547 2121-07-23 16:00:00
# 11660  18180702      63944  187913     249395  227543 2121-07-23 17:00:00
# 11661  18180703      63944  187913     249395  227546 2121-07-23 17:00:00
# 11662  18180704      63944  187913     249395  227547 2121-07-23 17:00:00
#
#                 storetime   cgid value valuenum  ... hadm_id seq_num  \
# 0     2168-04-14 22:21:00  19786    32       32  ...  129892       2
# 1     2168-04-14 22:21:00  19786    12       12  ...  129892       2
# 2     2168-04-14 22:21:00  19786    21       21  ...  129892       2
# 3     2168-04-14 22:21:00  19786     5        5  ...  129892       2
# 4     2168-04-15 00:18:00  19786    34       34  ...  129892       2
# ...                   ...    ...   ...      ...  ...     ...     ...
# 11658 2121-07-24 08:23:00  20088    78       78  ...  187913       8
# 11659 2121-07-23 16:08:00  19783    75       75  ...  187913       8
# 11660 2121-07-23 17:23:00  19783   5.5      5.5  ...  187913       8
# 11661 2121-07-23 17:23:00  19783    14       14  ...  187913       8
# 11662 2121-07-23 17:23:00  19783    79       79  ...  187913       8
#
#       icd9_code row_id                                label    abbreviation  \
# 0         42820  12721   Pulmonary Artery Pressure systolic            PAPs
# 1         42820  12722  Pulmonary Artery Pressure diastolic            PAPd
# 2         42820  12723       Pulmonary Artery Pressure mean            PAPm
# 3         42820  12729              Central Venous Pressure             CVP
# 4         42820  12721   Pulmonary Artery Pressure systolic            PAPs
# ...         ...    ...                                  ...             ...
# 11658     42820  14790                        SV (Arterial)   SV (Arterial)
# 11659     42820  14790                        SV (Arterial)   SV (Arterial)
# 11660     42820  14788                        CO (Arterial)   CO (Arterial)
# 11661     42820  14789                       SVV (Arterial)  SVV (Arterial)
# 11662     42820  14790                        SV (Arterial)   SV (Arterial)
#
#          dbsource      linksto      category param_type
# 0      metavision  chartevents  Hemodynamics    Numeric
# 1      metavision  chartevents  Hemodynamics    Numeric
# 2      metavision  chartevents  Hemodynamics    Numeric
# 3      metavision  chartevents  Hemodynamics    Numeric
# 4      metavision  chartevents  Hemodynamics    Numeric
# ...           ...          ...           ...        ...
# 11658  metavision  chartevents  Hemodynamics    Numeric
# 11659  metavision  chartevents  Hemodynamics    Numeric
# 11660  metavision  chartevents  Hemodynamics    Numeric
# 11661  metavision  chartevents  Hemodynamics    Numeric
# 11662  metavision  chartevents  Hemodynamics    Numeric
#
# [11663 rows x 25 columns]

# %%
df_hf_s_.isna().sum()
# Out:
# row_id              0
# subject_id          0
# hadm_id             0
# icustay_id          0
# itemid              0
# charttime           0
# storetime           0
# cgid                0
# value               0
# valuenum            0
# valueuom            0
# warning             0
# error               0
# resultstatus    11663
# row_id              0
# hadm_id             0
# seq_num             0
# icd9_code           0
# row_id              0
# label               0
# abbreviation        0
# dbsource            0
# linksto             0
# category            0
# param_type          0
# dtype: int64

# %%
df_hf_s_['value'].values.astype(str)
df_hf_s_['value'] = np.where(np.char.isnumeric(df_hf_s_['value'].values.astype(str)), df_hf_s_['value'].values, 'NaN')

# %%
cols = df_hf_s_['label'].unique()
rows = df_hf_s_['subject_id'].unique()
df_mean, df_max, df_min, df_std, df_col, df_id = [], [], [], [], [], []
df_hf_s_1 = pd.DataFrame(index=rows, columns=cols)

for ind in df_hf_s_1.index:
    df_s_1 = df_hf_s_[df_hf_s_['subject_id']==ind]
    for col in df_hf_s_1.columns:
        df_hf_s_1.loc[ind,col] = df_s_1[df_s_1['label']==col].value.astype('float64').mean()
        
df_hf_s_1
# Out:
#       Pulmonary Artery Pressure systolic Pulmonary Artery Pressure diastolic  \
# 1767                             37.0714                             17.5714
# 2639                                45.5                             25.4048
# 3513                                 NaN                                 NaN
# 3969                                 NaN                                 NaN
# 5244                                 NaN                                 NaN
# 5727                                 NaN                                 NaN
# 6901                                 NaN                                 NaN
# 7449                             37.2973                              20.027
# 8498                                 NaN                                 NaN
# 11242                                NaN                                 NaN
# 11993                                NaN                                 NaN
# 14768                                NaN                                 NaN
# 14230                            38.0682                             21.3409
# 18982                                NaN                                 NaN
# 19569                                NaN                                 NaN
# 20747                                NaN                                 NaN
# 23450                                NaN                                 NaN
# 23161                                NaN                                 NaN
# 23680                                NaN                                 NaN
# 27603                                NaN                                 NaN
# 28221                            27.4483                             16.3448
# 29621                                NaN                                 NaN
# 31994                            44.7381                             21.9048
# 32447                            37.0244                             21.5157
# 40334                                NaN                                 NaN
# 44848                                NaN                                 NaN
# 48292                                NaN                                 NaN
# 47816                               36.5                                16.5
# 48040                                NaN                                 NaN
# 48826                                NaN                                 NaN
# 49984                                NaN                                 NaN
# 55515                            30.0968                             15.2258
# 56201                            40.9524                             20.1905
# 56583                                NaN                                 NaN
# 59516                                NaN                                 NaN
# 60969                            47.9275                             22.8551
# 60354                            32.2957                             16.6757
# 63944                                NaN                                 NaN
# 63467                            36.0755                             21.8302
# 64980                            36.9231                             21.1538
# 68389                                NaN                                 NaN
# 68956                                NaN                                 NaN
# 71108                                NaN                                 NaN
# 74160                            37.7778                             20.0741
# 80274                                NaN                                 NaN
# 80956                            49.9531                             28.3594
# 83341                                NaN                                 NaN
# 87053                                NaN                                 NaN
# 87754                            48.8309                             24.1765
# 89008                            44.5429                             24.8857
# 91603                            39.3625                                15.6
# 90680                            32.6613                             19.3871
# 92287                                NaN                                 NaN
# 92195                                NaN                                 NaN
# 10954                                NaN                                 NaN
#
#       Pulmonary Artery Pressure mean Central Venous Pressure  \
# 1767                         26.3571                  12.375
# 2639                            33.6                 16.6552
# 3513                             NaN                 16.8289
# 3969                             NaN                 34.2919
# 5244                             NaN                 83.1354
# 5727                             NaN                 17.4545
# 6901                             NaN                 9.95455
# 7449                         26.8333                 12.3514
# 8498                             NaN                  13.875
# 11242                            NaN                 6.42857
# 11993                            NaN                 21.4925
# 14768                            NaN                      19
# 14230                          28.25                 14.0909
# 18982                            NaN                   13.14
# 19569                            NaN                 11.4348
# 20747                            NaN                   15.82
# 23450                            NaN                 60.6768
# 23161                            NaN                 14.5455
# 23680                            NaN                 26.5368
# 27603                            NaN                      26
# 28221                        21.4828                 19.0345
# 29621                            NaN                 29.4651
# 31994                        30.8554                 18.0633
# 32447                        28.2947                 19.5199
# 40334                             78                 22.4688
# 44848                            NaN                     9.5
# 48292                            NaN                 43.2222
# 47816                             24                 7.47727
# 48040                            NaN                     6.5
# 48826                            NaN                 8.93197
# 49984                            NaN                 9.52778
# 55515                        20.6452                 11.0645
# 56201                        28.4286                 10.9524
# 56583                            NaN                 12.1786
# 59516                            NaN                 29.9091
# 60969                        32.5362                 21.5797
# 60354                        22.6216                 16.6033
# 63944                            NaN                  6.4375
# 63467                        27.0377                 14.4167
# 64980                        26.8846                 12.7308
# 68389                            NaN                 15.6508
# 68956                            NaN                 26.3529
# 71108                            NaN                 14.1849
# 74160                          27.24                 13.0323
# 80274                            NaN                 17.2148
# 80956                        37.0635                 21.3659
# 83341                            NaN                   5.625
# 87053                            NaN                 17.0625
# 87754                        33.2296                 15.6475
# 89008                        32.6286                 17.4857
# 91603                        22.9875                 8.23457
# 90680                        26.6452                  15.371
# 92287                            NaN                 74.7931
# 92195                            NaN                 8.16393
# 10954                            NaN                     NaN
#
#       Cardiac Output (thermodilution)     SvO2 PA Line cm Mark  \
# 1767                              NaN  70.9216              48
# 2639                              NaN       80             NaN
# 3513                              NaN      NaN             NaN
# 3969                              NaN      NaN             NaN
# 5244                              NaN  76.9615             NaN
# 5727                              NaN      NaN             NaN
# 6901                              NaN      NaN             NaN
# 7449                              NaN       69          54.125
# 8498                              NaN      NaN             NaN
# 11242                             NaN      NaN             NaN
# 11993                             NaN      NaN             NaN
# 14768                             NaN      NaN             NaN
# 14230                             NaN  59.9737              44
# 18982                             NaN      NaN             NaN
# 19569                             NaN      NaN             NaN
# 20747                             NaN      NaN             NaN
# 23450                             NaN      NaN             NaN
# 23161                             NaN     59.5             NaN
# 23680                             NaN      NaN             NaN
# 27603                             NaN      NaN             NaN
# 28221                             NaN      NaN              49
# 29621                             NaN      NaN             NaN
# 31994                             NaN  69.1299              48
# 32447                             NaN  63.9858            51.6
# 40334                             NaN      NaN             NaN
# 44848                             NaN      NaN             NaN
# 48292                             NaN      NaN             NaN
# 47816                             NaN      NaN             NaN
# 48040                             NaN      NaN             NaN
# 48826                             NaN      NaN             NaN
# 49984                             NaN      NaN             NaN
# 55515                             NaN      NaN              50
# 56201                             NaN  64.2941              55
# 56583                             NaN      NaN             NaN
# 59516                             NaN      NaN             NaN
# 60969                             NaN      NaN              51
# 60354                             NaN       60              46
# 63944                             NaN      NaN             NaN
# 63467                             NaN       75             NaN
# 64980                             NaN      NaN              60
# 68389                             NaN      NaN             NaN
# 68956                             NaN      NaN             NaN
# 71108                             NaN      NaN             NaN
# 74160                             NaN      NaN             NaN
# 80274                             NaN      NaN             NaN
# 80956                             NaN  70.8205              48
# 83341                             NaN      NaN             NaN
# 87053                             NaN      NaN             NaN
# 87754                             NaN  62.3185              58
# 89008                             NaN  72.5517              49
# 91603                             NaN  62.2877              50
# 90680                             NaN  73.4545              50
# 92287                             NaN      NaN             NaN
# 92195                             NaN      NaN             NaN
# 10954                             NaN      NaN             NaN
#
#       Intra Cranial Pressure Cardiac Output (CCO) ScvO2 (Presep)  \
# 1767                     NaN                    4            NaN
# 2639                     NaN                  NaN            NaN
# 3513                     NaN                  NaN            NaN
# 3969                     NaN                  NaN            NaN
# 5244                     NaN                  NaN            NaN
# 5727                     NaN                  NaN            NaN
# 6901                     NaN                  NaN            NaN
# 7449                     NaN                    5            NaN
# 8498                     NaN                  NaN        64.7857
# 11242                    NaN                  NaN            NaN
# 11993                    NaN                  NaN            NaN
# 14768                    NaN                  NaN            NaN
# 14230                    NaN                    3            NaN
# 18982                    NaN                  NaN            NaN
# 19569                    NaN                  NaN            NaN
# 20747                    NaN                  NaN            NaN
# 23450                    NaN                  NaN            NaN
# 23161                     15                  NaN            NaN
# 23680                    NaN                  NaN            NaN
# 27603                    NaN                  NaN            NaN
# 28221                    NaN                  NaN            NaN
# 29621                    NaN                  NaN            NaN
# 31994                    NaN                  4.4            NaN
# 32447                    NaN              3.84848            NaN
# 40334                    NaN                  NaN            NaN
# 44848                    NaN                  NaN            NaN
# 48292                    NaN                  NaN            NaN
# 47816                    NaN                  NaN            NaN
# 48040                    NaN                  NaN            NaN
# 48826                    NaN                  NaN            NaN
# 49984                    NaN                  NaN            NaN
# 55515                    NaN                  NaN            NaN
# 56201                    NaN                  NaN            NaN
# 56583                    NaN                  NaN            NaN
# 59516                    NaN                  NaN            NaN
# 60969                    NaN                  NaN            NaN
# 60354                    NaN                  NaN            NaN
# 63944                    NaN                  NaN            NaN
# 63467                    NaN                  NaN            NaN
# 64980                    NaN                  NaN            NaN
# 68389                    NaN                  NaN            NaN
# 68956                    NaN                  NaN            NaN
# 71108                    NaN                  NaN            NaN
# 74160                    NaN                  NaN            NaN
# 80274                    NaN                  NaN            NaN
# 80956                    NaN                   80            NaN
# 83341                    NaN                  NaN            NaN
# 87053                    NaN                  NaN            NaN
# 87754                    NaN              6.14286            NaN
# 89008                    NaN                  5.6            NaN
# 91603                    NaN              4.57143            NaN
# 90680                    NaN                    4            NaN
# 92287                    NaN                  NaN            NaN
# 92195                    NaN                  NaN            NaN
# 10954                    NaN                  NaN            NaN
#
#       SVV (Arterial) SV (Arterial) CO (Arterial)
# 1767             NaN           NaN           NaN
# 2639             NaN           NaN           NaN
# 3513             NaN           NaN           NaN
# 3969             NaN           NaN           NaN
# 5244             NaN           NaN           NaN
# 5727             NaN           NaN           NaN
# 6901             NaN           NaN           NaN
# 7449             NaN           NaN           NaN
# 8498             NaN           NaN           NaN
# 11242            NaN           NaN           NaN
# 11993            NaN           NaN           NaN
# 14768            NaN           NaN           NaN
# 14230            NaN           NaN           NaN
# 18982            NaN           NaN           NaN
# 19569            NaN           NaN           NaN
# 20747            NaN           NaN           NaN
# 23450            NaN           NaN           NaN
# 23161            NaN           NaN           NaN
# 23680        9.55714       97.5735       6.92308
# 27603            NaN           NaN           NaN
# 28221            NaN           NaN           NaN
# 29621            NaN           NaN           NaN
# 31994            NaN           NaN           NaN
# 32447            NaN           NaN           NaN
# 40334            NaN           NaN           NaN
# 44848            NaN           NaN           NaN
# 48292            NaN           NaN           NaN
# 47816            NaN           NaN           NaN
# 48040            NaN           NaN           NaN
# 48826            NaN           NaN           NaN
# 49984            NaN           NaN           NaN
# 55515            NaN           NaN           NaN
# 56201            NaN           NaN           NaN
# 56583            NaN           NaN           NaN
# 59516            NaN           NaN           NaN
# 60969            NaN           NaN           NaN
# 60354            NaN           NaN           NaN
# 63944        8.62069       75.5862             5
# 63467            NaN           NaN           NaN
# 64980            NaN           NaN           NaN
# 68389            NaN           NaN           NaN
# 68956            NaN           NaN           NaN
# 71108            NaN           NaN           NaN
# 74160            NaN           NaN           NaN
# 80274            NaN           NaN           NaN
# 80956            NaN           NaN           NaN
# 83341            NaN           NaN           NaN
# 87053            NaN           NaN           NaN
# 87754            NaN           NaN           NaN
# 89008            NaN           NaN           NaN
# 91603            NaN           NaN           NaN
# 90680            NaN           NaN           NaN
# 92287            NaN           NaN           NaN
# 92195            NaN           NaN           NaN
# 10954        15.9524       68.7407             5

# %%
df_hf_s_1.isna().sum()
# Out:
# Pulmonary Artery Pressure systolic     35
# Pulmonary Artery Pressure diastolic    35
# Pulmonary Artery Pressure mean         34
# Central Venous Pressure                 1
# Cardiac Output (thermodilution)        55
# SvO2                                   39
# PA Line cm Mark                        39
# Intra Cranial Pressure                 54
# Cardiac Output (CCO)                   45
# ScvO2 (Presep)                         54
# SVV (Arterial)                         52
# SV (Arterial)                          52
# CO (Arterial)                          52
# dtype: int64

# %%
max_number_of_nas = 500
df_hf_s_2 = df_hf_s_1.loc[:, (df_hf_s_1.isnull().sum(axis=0) <= max_number_of_nas)]
df_hf_s_2
# Out:
#       Pulmonary Artery Pressure systolic Pulmonary Artery Pressure diastolic  \
# 1767                             37.0714                             17.5714
# 2639                                45.5                             25.4048
# 3513                                 NaN                                 NaN
# 3969                                 NaN                                 NaN
# 5244                                 NaN                                 NaN
# 5727                                 NaN                                 NaN
# 6901                                 NaN                                 NaN
# 7449                             37.2973                              20.027
# 8498                                 NaN                                 NaN
# 11242                                NaN                                 NaN
# 11993                                NaN                                 NaN
# 14768                                NaN                                 NaN
# 14230                            38.0682                             21.3409
# 18982                                NaN                                 NaN
# 19569                                NaN                                 NaN
# 20747                                NaN                                 NaN
# 23450                                NaN                                 NaN
# 23161                                NaN                                 NaN
# 23680                                NaN                                 NaN
# 27603                                NaN                                 NaN
# 28221                            27.4483                             16.3448
# 29621                                NaN                                 NaN
# 31994                            44.7381                             21.9048
# 32447                            37.0244                             21.5157
# 40334                                NaN                                 NaN
# 44848                                NaN                                 NaN
# 48292                                NaN                                 NaN
# 47816                               36.5                                16.5
# 48040                                NaN                                 NaN
# 48826                                NaN                                 NaN
# 49984                                NaN                                 NaN
# 55515                            30.0968                             15.2258
# 56201                            40.9524                             20.1905
# 56583                                NaN                                 NaN
# 59516                                NaN                                 NaN
# 60969                            47.9275                             22.8551
# 60354                            32.2957                             16.6757
# 63944                                NaN                                 NaN
# 63467                            36.0755                             21.8302
# 64980                            36.9231                             21.1538
# 68389                                NaN                                 NaN
# 68956                                NaN                                 NaN
# 71108                                NaN                                 NaN
# 74160                            37.7778                             20.0741
# 80274                                NaN                                 NaN
# 80956                            49.9531                             28.3594
# 83341                                NaN                                 NaN
# 87053                                NaN                                 NaN
# 87754                            48.8309                             24.1765
# 89008                            44.5429                             24.8857
# 91603                            39.3625                                15.6
# 90680                            32.6613                             19.3871
# 92287                                NaN                                 NaN
# 92195                                NaN                                 NaN
# 10954                                NaN                                 NaN
#
#       Pulmonary Artery Pressure mean Central Venous Pressure  \
# 1767                         26.3571                  12.375
# 2639                            33.6                 16.6552
# 3513                             NaN                 16.8289
# 3969                             NaN                 34.2919
# 5244                             NaN                 83.1354
# 5727                             NaN                 17.4545
# 6901                             NaN                 9.95455
# 7449                         26.8333                 12.3514
# 8498                             NaN                  13.875
# 11242                            NaN                 6.42857
# 11993                            NaN                 21.4925
# 14768                            NaN                      19
# 14230                          28.25                 14.0909
# 18982                            NaN                   13.14
# 19569                            NaN                 11.4348
# 20747                            NaN                   15.82
# 23450                            NaN                 60.6768
# 23161                            NaN                 14.5455
# 23680                            NaN                 26.5368
# 27603                            NaN                      26
# 28221                        21.4828                 19.0345
# 29621                            NaN                 29.4651
# 31994                        30.8554                 18.0633
# 32447                        28.2947                 19.5199
# 40334                             78                 22.4688
# 44848                            NaN                     9.5
# 48292                            NaN                 43.2222
# 47816                             24                 7.47727
# 48040                            NaN                     6.5
# 48826                            NaN                 8.93197
# 49984                            NaN                 9.52778
# 55515                        20.6452                 11.0645
# 56201                        28.4286                 10.9524
# 56583                            NaN                 12.1786
# 59516                            NaN                 29.9091
# 60969                        32.5362                 21.5797
# 60354                        22.6216                 16.6033
# 63944                            NaN                  6.4375
# 63467                        27.0377                 14.4167
# 64980                        26.8846                 12.7308
# 68389                            NaN                 15.6508
# 68956                            NaN                 26.3529
# 71108                            NaN                 14.1849
# 74160                          27.24                 13.0323
# 80274                            NaN                 17.2148
# 80956                        37.0635                 21.3659
# 83341                            NaN                   5.625
# 87053                            NaN                 17.0625
# 87754                        33.2296                 15.6475
# 89008                        32.6286                 17.4857
# 91603                        22.9875                 8.23457
# 90680                        26.6452                  15.371
# 92287                            NaN                 74.7931
# 92195                            NaN                 8.16393
# 10954                            NaN                     NaN
#
#       Cardiac Output (thermodilution)     SvO2 PA Line cm Mark  \
# 1767                              NaN  70.9216              48
# 2639                              NaN       80             NaN
# 3513                              NaN      NaN             NaN
# 3969                              NaN      NaN             NaN
# 5244                              NaN  76.9615             NaN
# 5727                              NaN      NaN             NaN
# 6901                              NaN      NaN             NaN
# 7449                              NaN       69          54.125
# 8498                              NaN      NaN             NaN
# 11242                             NaN      NaN             NaN
# 11993                             NaN      NaN             NaN
# 14768                             NaN      NaN             NaN
# 14230                             NaN  59.9737              44
# 18982                             NaN      NaN             NaN
# 19569                             NaN      NaN             NaN
# 20747                             NaN      NaN             NaN
# 23450                             NaN      NaN             NaN
# 23161                             NaN     59.5             NaN
# 23680                             NaN      NaN             NaN
# 27603                             NaN      NaN             NaN
# 28221                             NaN      NaN              49
# 29621                             NaN      NaN             NaN
# 31994                             NaN  69.1299              48
# 32447                             NaN  63.9858            51.6
# 40334                             NaN      NaN             NaN
# 44848                             NaN      NaN             NaN
# 48292                             NaN      NaN             NaN
# 47816                             NaN      NaN             NaN
# 48040                             NaN      NaN             NaN
# 48826                             NaN      NaN             NaN
# 49984                             NaN      NaN             NaN
# 55515                             NaN      NaN              50
# 56201                             NaN  64.2941              55
# 56583                             NaN      NaN             NaN
# 59516                             NaN      NaN             NaN
# 60969                             NaN      NaN              51
# 60354                             NaN       60              46
# 63944                             NaN      NaN             NaN
# 63467                             NaN       75             NaN
# 64980                             NaN      NaN              60
# 68389                             NaN      NaN             NaN
# 68956                             NaN      NaN             NaN
# 71108                             NaN      NaN             NaN
# 74160                             NaN      NaN             NaN
# 80274                             NaN      NaN             NaN
# 80956                             NaN  70.8205              48
# 83341                             NaN      NaN             NaN
# 87053                             NaN      NaN             NaN
# 87754                             NaN  62.3185              58
# 89008                             NaN  72.5517              49
# 91603                             NaN  62.2877              50
# 90680                             NaN  73.4545              50
# 92287                             NaN      NaN             NaN
# 92195                             NaN      NaN             NaN
# 10954                             NaN      NaN             NaN
#
#       Intra Cranial Pressure Cardiac Output (CCO) ScvO2 (Presep)  \
# 1767                     NaN                    4            NaN
# 2639                     NaN                  NaN            NaN
# 3513                     NaN                  NaN            NaN
# 3969                     NaN                  NaN            NaN
# 5244                     NaN                  NaN            NaN
# 5727                     NaN                  NaN            NaN
# 6901                     NaN                  NaN            NaN
# 7449                     NaN                    5            NaN
# 8498                     NaN                  NaN        64.7857
# 11242                    NaN                  NaN            NaN
# 11993                    NaN                  NaN            NaN
# 14768                    NaN                  NaN            NaN
# 14230                    NaN                    3            NaN
# 18982                    NaN                  NaN            NaN
# 19569                    NaN                  NaN            NaN
# 20747                    NaN                  NaN            NaN
# 23450                    NaN                  NaN            NaN
# 23161                     15                  NaN            NaN
# 23680                    NaN                  NaN            NaN
# 27603                    NaN                  NaN            NaN
# 28221                    NaN                  NaN            NaN
# 29621                    NaN                  NaN            NaN
# 31994                    NaN                  4.4            NaN
# 32447                    NaN              3.84848            NaN
# 40334                    NaN                  NaN            NaN
# 44848                    NaN                  NaN            NaN
# 48292                    NaN                  NaN            NaN
# 47816                    NaN                  NaN            NaN
# 48040                    NaN                  NaN            NaN
# 48826                    NaN                  NaN            NaN
# 49984                    NaN                  NaN            NaN
# 55515                    NaN                  NaN            NaN
# 56201                    NaN                  NaN            NaN
# 56583                    NaN                  NaN            NaN
# 59516                    NaN                  NaN            NaN
# 60969                    NaN                  NaN            NaN
# 60354                    NaN                  NaN            NaN
# 63944                    NaN                  NaN            NaN
# 63467                    NaN                  NaN            NaN
# 64980                    NaN                  NaN            NaN
# 68389                    NaN                  NaN            NaN
# 68956                    NaN                  NaN            NaN
# 71108                    NaN                  NaN            NaN
# 74160                    NaN                  NaN            NaN
# 80274                    NaN                  NaN            NaN
# 80956                    NaN                   80            NaN
# 83341                    NaN                  NaN            NaN
# 87053                    NaN                  NaN            NaN
# 87754                    NaN              6.14286            NaN
# 89008                    NaN                  5.6            NaN
# 91603                    NaN              4.57143            NaN
# 90680                    NaN                    4            NaN
# 92287                    NaN                  NaN            NaN
# 92195                    NaN                  NaN            NaN
# 10954                    NaN                  NaN            NaN
#
#       SVV (Arterial) SV (Arterial) CO (Arterial)
# 1767             NaN           NaN           NaN
# 2639             NaN           NaN           NaN
# 3513             NaN           NaN           NaN
# 3969             NaN           NaN           NaN
# 5244             NaN           NaN           NaN
# 5727             NaN           NaN           NaN
# 6901             NaN           NaN           NaN
# 7449             NaN           NaN           NaN
# 8498             NaN           NaN           NaN
# 11242            NaN           NaN           NaN
# 11993            NaN           NaN           NaN
# 14768            NaN           NaN           NaN
# 14230            NaN           NaN           NaN
# 18982            NaN           NaN           NaN
# 19569            NaN           NaN           NaN
# 20747            NaN           NaN           NaN
# 23450            NaN           NaN           NaN
# 23161            NaN           NaN           NaN
# 23680        9.55714       97.5735       6.92308
# 27603            NaN           NaN           NaN
# 28221            NaN           NaN           NaN
# 29621            NaN           NaN           NaN
# 31994            NaN           NaN           NaN
# 32447            NaN           NaN           NaN
# 40334            NaN           NaN           NaN
# 44848            NaN           NaN           NaN
# 48292            NaN           NaN           NaN
# 47816            NaN           NaN           NaN
# 48040            NaN           NaN           NaN
# 48826            NaN           NaN           NaN
# 49984            NaN           NaN           NaN
# 55515            NaN           NaN           NaN
# 56201            NaN           NaN           NaN
# 56583            NaN           NaN           NaN
# 59516            NaN           NaN           NaN
# 60969            NaN           NaN           NaN
# 60354            NaN           NaN           NaN
# 63944        8.62069       75.5862             5
# 63467            NaN           NaN           NaN
# 64980            NaN           NaN           NaN
# 68389            NaN           NaN           NaN
# 68956            NaN           NaN           NaN
# 71108            NaN           NaN           NaN
# 74160            NaN           NaN           NaN
# 80274            NaN           NaN           NaN
# 80956            NaN           NaN           NaN
# 83341            NaN           NaN           NaN
# 87053            NaN           NaN           NaN
# 87754            NaN           NaN           NaN
# 89008            NaN           NaN           NaN
# 91603            NaN           NaN           NaN
# 90680            NaN           NaN           NaN
# 92287            NaN           NaN           NaN
# 92195            NaN           NaN           NaN
# 10954        15.9524       68.7407             5

# %%
max_number_of_nas = 35
df_hf_s_3 = df_hf_s_2.dropna(thresh=max_number_of_nas)
df_hf_s_3
# Out:
# Empty DataFrame
# Columns: [Pulmonary Artery Pressure systolic, Pulmonary Artery Pressure diastolic, Pulmonary Artery Pressure mean, Central Venous Pressure, Cardiac Output (thermodilution), SvO2, PA Line cm Mark, Intra Cranial Pressure, Cardiac Output (CCO), ScvO2 (Presep), SVV (Arterial), SV (Arterial), CO (Arterial)]
# Index: []

# %%
max_number_of_nas = 25
df_hf_s_3 = df_hf_s_2.dropna(thresh=max_number_of_nas)
df_hf_s_3
# Out:
# Empty DataFrame
# Columns: [Pulmonary Artery Pressure systolic, Pulmonary Artery Pressure diastolic, Pulmonary Artery Pressure mean, Central Venous Pressure, Cardiac Output (thermodilution), SvO2, PA Line cm Mark, Intra Cranial Pressure, Cardiac Output (CCO), ScvO2 (Presep), SVV (Arterial), SV (Arterial), CO (Arterial)]
# Index: []

# %%
max_number_of_nas = 15
df_hf_s_3 = df_hf_s_2.dropna(thresh=max_number_of_nas)
df_hf_s_3
# Out:
# Empty DataFrame
# Columns: [Pulmonary Artery Pressure systolic, Pulmonary Artery Pressure diastolic, Pulmonary Artery Pressure mean, Central Venous Pressure, Cardiac Output (thermodilution), SvO2, PA Line cm Mark, Intra Cranial Pressure, Cardiac Output (CCO), ScvO2 (Presep), SVV (Arterial), SV (Arterial), CO (Arterial)]
# Index: []

# %%
max_number_of_nas = 5
df_hf_s_3 = df_hf_s_2.dropna(thresh=max_number_of_nas)
df_hf_s_3
# Out:
#       Pulmonary Artery Pressure systolic Pulmonary Artery Pressure diastolic  \
# 1767                             37.0714                             17.5714
# 2639                                45.5                             25.4048
# 7449                             37.2973                              20.027
# 14230                            38.0682                             21.3409
# 28221                            27.4483                             16.3448
# 31994                            44.7381                             21.9048
# 32447                            37.0244                             21.5157
# 55515                            30.0968                             15.2258
# 56201                            40.9524                             20.1905
# 60969                            47.9275                             22.8551
# 60354                            32.2957                             16.6757
# 63467                            36.0755                             21.8302
# 64980                            36.9231                             21.1538
# 80956                            49.9531                             28.3594
# 87754                            48.8309                             24.1765
# 89008                            44.5429                             24.8857
# 91603                            39.3625                                15.6
# 90680                            32.6613                             19.3871
#
#       Pulmonary Artery Pressure mean Central Venous Pressure  \
# 1767                         26.3571                  12.375
# 2639                            33.6                 16.6552
# 7449                         26.8333                 12.3514
# 14230                          28.25                 14.0909
# 28221                        21.4828                 19.0345
# 31994                        30.8554                 18.0633
# 32447                        28.2947                 19.5199
# 55515                        20.6452                 11.0645
# 56201                        28.4286                 10.9524
# 60969                        32.5362                 21.5797
# 60354                        22.6216                 16.6033
# 63467                        27.0377                 14.4167
# 64980                        26.8846                 12.7308
# 80956                        37.0635                 21.3659
# 87754                        33.2296                 15.6475
# 89008                        32.6286                 17.4857
# 91603                        22.9875                 8.23457
# 90680                        26.6452                  15.371
#
#       Cardiac Output (thermodilution)     SvO2 PA Line cm Mark  \
# 1767                              NaN  70.9216              48
# 2639                              NaN       80             NaN
# 7449                              NaN       69          54.125
# 14230                             NaN  59.9737              44
# 28221                             NaN      NaN              49
# 31994                             NaN  69.1299              48
# 32447                             NaN  63.9858            51.6
# 55515                             NaN      NaN              50
# 56201                             NaN  64.2941              55
# 60969                             NaN      NaN              51
# 60354                             NaN       60              46
# 63467                             NaN       75             NaN
# 64980                             NaN      NaN              60
# 80956                             NaN  70.8205              48
# 87754                             NaN  62.3185              58
# 89008                             NaN  72.5517              49
# 91603                             NaN  62.2877              50
# 90680                             NaN  73.4545              50
#
#       Intra Cranial Pressure Cardiac Output (CCO) ScvO2 (Presep)  \
# 1767                     NaN                    4            NaN
# 2639                     NaN                  NaN            NaN
# 7449                     NaN                    5            NaN
# 14230                    NaN                    3            NaN
# 28221                    NaN                  NaN            NaN
# 31994                    NaN                  4.4            NaN
# 32447                    NaN              3.84848            NaN
# 55515                    NaN                  NaN            NaN
# 56201                    NaN                  NaN            NaN
# 60969                    NaN                  NaN            NaN
# 60354                    NaN                  NaN            NaN
# 63467                    NaN                  NaN            NaN
# 64980                    NaN                  NaN            NaN
# 80956                    NaN                   80            NaN
# 87754                    NaN              6.14286            NaN
# 89008                    NaN                  5.6            NaN
# 91603                    NaN              4.57143            NaN
# 90680                    NaN                    4            NaN
#
#       SVV (Arterial) SV (Arterial) CO (Arterial)
# 1767             NaN           NaN           NaN
# 2639             NaN           NaN           NaN
# 7449             NaN           NaN           NaN
# 14230            NaN           NaN           NaN
# 28221            NaN           NaN           NaN
# 31994            NaN           NaN           NaN
# 32447            NaN           NaN           NaN
# 55515            NaN           NaN           NaN
# 56201            NaN           NaN           NaN
# 60969            NaN           NaN           NaN
# 60354            NaN           NaN           NaN
# 63467            NaN           NaN           NaN
# 64980            NaN           NaN           NaN
# 80956            NaN           NaN           NaN
# 87754            NaN           NaN           NaN
# 89008            NaN           NaN           NaN
# 91603            NaN           NaN           NaN
# 90680            NaN           NaN           NaN

# %% [markdown]
# The number of empty values, in this case NaNs, is high for this subsample. Only a threshold of 15 NaNs values removes all rows from the created DataFrame, making the modeling step difficult and especially inaccurate. Thus, it is necessary to include more information, considering not only hemodynamic data but further physiological measurements and lab exams data.

# %% [markdown]
# ### Additional (Physiological) Data
# From the MIMIC database, several additional physiological measurements and lab exams data is available. To improve the dataframe selection, relevant items were selected in addition to hemodynamics. Specifically, the categories arterial blood gas (ABG) data, hematology, chemistry, fluids, blood products/colloids, labs, cardiovascular, tandem heart and Non-invasive cardiac output monitor (NICOM).

# %% [markdown]
# #### Systolic Heart Failure - Subsample Population
# Again, the subsample population of patients with Systolic Heart Failure is selected, and all selected physiological measurement data are analyzed in order to obtain a DataFrame to model the data.

# %%
query = \
"""
SELECT *
FROM chartevents c
INNER JOIN diagnoses_icd d ON c.subject_id = d.subject_id
INNER JOIN d_items d_i ON c.itemid = d_i.itemid
WHERE d.icd9_code = '42820' AND (d_i.category = 'Hemodynamics' OR d_i.category = 'ABG' OR d_i.category = 'Hematology' 
OR d_i.category = 'Chemistry' OR d_i.category = 'Fluids - Other (Not In Use)' OR d_i.category = 'Blood Products/Colloids' 
OR d_i.category = 'Labs' OR d_i.category = 'Cardiovascular (Pacer Data)' OR d_i.category = 'Tandem Heart' 
OR d_i.category = 'NICOM')
"""
df_hf_sys = pd.read_sql_query(query, con)
df_hf_sys
# Out:
#           row_id  subject_id  hadm_id  icustay_id  itemid           charttime  \
# 0        3553129       28044   116475    265193.0  227466 2145-01-16 18:30:00
# 1        3553128       28044   116475    265193.0  227442 2145-01-16 18:30:00
# 2        3553127       28044   116475    265193.0  225677 2145-01-16 18:30:00
# 3        3553126       28044   116475    265193.0  225625 2145-01-16 18:30:00
# 4        3553124       28044   116475    265193.0  227467 2145-01-16 03:46:00
# ...          ...         ...      ...         ...     ...                 ...
# 277220  90575581       10928   108955    220051.0     791 2114-12-27 03:00:00
# 277221  90575580       10928   108955    220051.0     788 2114-12-27 03:00:00
# 277222  90575579       10928   108955    220051.0     787 2114-12-27 03:00:00
# 277223  90575578       10928   108955    220051.0     786 2114-12-27 03:00:00
# 277224  90575577       10928   108955    220051.0     781 2114-12-27 03:00:00
#
#                  storetime   cgid               value  valuenum  ... row_id  \
# 0      2145-01-16 19:33:00  20889                58.6      58.6  ...  14827
# 1      2145-01-16 19:22:00  20889                 4.5       4.5  ...  14756
# 2      2145-01-16 19:22:00  20889                 4.7       4.7  ...  14119
# 3      2145-01-16 19:22:00  20889                 9.1       9.1  ...  14082
# 4      2145-01-16 05:45:00  20889                 1.5       1.5  ...  14828
# ...                    ...    ...                 ...       ...  ...    ...
# 277220 2114-12-27 04:47:00  15331                  .6       0.6  ...    710
# 277221 2114-12-27 04:47:00  15331                 104     104.0  ...    708
# 277222 2114-12-27 04:47:00  15331                  28      28.0  ...    707
# 277223 2114-12-27 04:47:00  15331  8.6999998092651367       8.7  ...    706
# 277224 2114-12-27 04:47:00  15331                   8       8.0  ...    701
#
#         itemid                label         abbreviation    dbsource  \
# 0       227466                  PTT                  PTT  metavision
# 1       227442    Potassium (serum)    Potassium (serum)  metavision
# 2       225677          Phosphorous          Phosphorous  metavision
# 3       225625  Calcium non-ionized  Calcium non-ionized  metavision
# 4       227467                  INR                  INR  metavision
# ...        ...                  ...                  ...         ...
# 277220     791   Creatinine (0-1.3)                 None     carevue
# 277221     788   Chloride (100-112)                 None     carevue
# 277222     787       Carbon Dioxide                 None     carevue
# 277223     786   Calcium (8.4-10.2)                 None     carevue
# 277224     781           BUN (6-20)                 None     carevue
#
#             linksto   category  unitname        param_type conceptid
# 0       chartevents       Labs      None  Numeric with tag      None
# 1       chartevents       Labs      None  Numeric with tag      None
# 2       chartevents       Labs      None           Numeric      None
# 3       chartevents       Labs      None           Numeric      None
# 4       chartevents       Labs      None  Numeric with tag      None
# ...             ...        ...       ...               ...       ...
# 277220  chartevents  Chemistry      None              None      None
# 277221  chartevents  Chemistry      None              None      None
# 277222  chartevents  Chemistry      None              None      None
# 277223  chartevents  Chemistry      None              None      None
# 277224  chartevents  Chemistry      None              None      None
#
# [277225 rows x 30 columns]

# %%
# Remove all data that parameter type is 'Text'
df_hf_sys_col = df_hf_sys.T.drop_duplicates().T
df_hf_sys_1 = df_hf_sys_col[df_hf_sys_col['param_type'] != 'Text']
df_hf_sys_1
# Out:
#           row_id subject_id hadm_id icustay_id  itemid           charttime  \
# 0        3553129      28044  116475     265193  227466 2145-01-16 18:30:00
# 1        3553128      28044  116475     265193  227442 2145-01-16 18:30:00
# 2        3553127      28044  116475     265193  225677 2145-01-16 18:30:00
# 3        3553126      28044  116475     265193  225625 2145-01-16 18:30:00
# 4        3553124      28044  116475     265193  227467 2145-01-16 03:46:00
# ...          ...        ...     ...        ...     ...                 ...
# 277220  90575581      10928  108955     220051     791 2114-12-27 03:00:00
# 277221  90575580      10928  108955     220051     788 2114-12-27 03:00:00
# 277222  90575579      10928  108955     220051     787 2114-12-27 03:00:00
# 277223  90575578      10928  108955     220051     786 2114-12-27 03:00:00
# 277224  90575577      10928  108955     220051     781 2114-12-27 03:00:00
#
#                  storetime   cgid               value valuenum  ... icd9_code  \
# 0      2145-01-16 19:33:00  20889                58.6     58.6  ...     42820
# 1      2145-01-16 19:22:00  20889                 4.5      4.5  ...     42820
# 2      2145-01-16 19:22:00  20889                 4.7      4.7  ...     42820
# 3      2145-01-16 19:22:00  20889                 9.1      9.1  ...     42820
# 4      2145-01-16 05:45:00  20889                 1.5      1.5  ...     42820
# ...                    ...    ...                 ...      ...  ...       ...
# 277220 2114-12-27 04:47:00  15331                  .6      0.6  ...     42820
# 277221 2114-12-27 04:47:00  15331                 104      104  ...     42820
# 277222 2114-12-27 04:47:00  15331                  28       28  ...     42820
# 277223 2114-12-27 04:47:00  15331  8.6999998092651367      8.7  ...     42820
# 277224 2114-12-27 04:47:00  15331                   8        8  ...     42820
#
#        row_id                label         abbreviation    dbsource  \
# 0       14827                  PTT                  PTT  metavision
# 1       14756    Potassium (serum)    Potassium (serum)  metavision
# 2       14119          Phosphorous          Phosphorous  metavision
# 3       14082  Calcium non-ionized  Calcium non-ionized  metavision
# 4       14828                  INR                  INR  metavision
# ...       ...                  ...                  ...         ...
# 277220    710   Creatinine (0-1.3)                 None     carevue
# 277221    708   Chloride (100-112)                 None     carevue
# 277222    707       Carbon Dioxide                 None     carevue
# 277223    706   Calcium (8.4-10.2)                 None     carevue
# 277224    701           BUN (6-20)                 None     carevue
#
#             linksto   category unitname        param_type conceptid
# 0       chartevents       Labs     None  Numeric with tag      None
# 1       chartevents       Labs     None  Numeric with tag      None
# 2       chartevents       Labs     None           Numeric      None
# 3       chartevents       Labs     None           Numeric      None
# 4       chartevents       Labs     None  Numeric with tag      None
# ...             ...        ...      ...               ...       ...
# 277220  chartevents  Chemistry     None              None      None
# 277221  chartevents  Chemistry     None              None      None
# 277222  chartevents  Chemistry     None              None      None
# 277223  chartevents  Chemistry     None              None      None
# 277224  chartevents  Chemistry     None              None      None
#
# [275723 rows x 28 columns]

# %%
df_hf_sys_1.isna().sum()
# Out:
# row_id               0
# subject_id           0
# hadm_id              0
# icustay_id         162
# itemid               0
# charttime            0
# storetime            0
# cgid                 0
# value              743
# valuenum          1929
# valueuom        158469
# warning         196841
# error           196841
# resultstatus     78915
# stopped          78882
# row_id               0
# hadm_id              0
# seq_num              0
# icd9_code            0
# row_id               0
# label                0
# abbreviation    196841
# dbsource             0
# linksto              0
# category             0
# unitname        196841
# param_type      196841
# conceptid       275723
# dtype: int64

# %%
df_hf_sys_1['value'].values.astype(str)
df_hf_sys_1['value'] = np.where(np.char.isnumeric(df_hf_sys_1['value'].values.astype(str)), df_hf_sys_1['value'].values, 'NaN')
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
cols = df_hf_sys_1['label'].unique()
rows = df_hf_sys_1['subject_id'].unique()
df_mean, df_max, df_min, df_std, df_col, df_id = [], [], [], [], [], []
df_hf_s = pd.DataFrame(index=rows, columns=cols)

for ind in df_hf_s.index:
    df_s = df_hf_sys_1[df_hf_sys_1['subject_id']==ind]
    for col in df_hf_s.columns:
        df_hf_s.loc[ind,col] = df_s[df_s['label']==col].value.astype('float64').mean()
        
df_hf_s
# Out:
#        PTT Potassium (serum) Phosphorous Calcium non-ionized  INR  \
# 28044   61                 4           4                   9  NaN
# 92195  150           4.66667         NaN                   9    2
# 12987  NaN               NaN         NaN                 NaN  NaN
# 43632  NaN                 4           2                   8  NaN
# 7105   NaN               NaN         NaN                 NaN  NaN
# ...    ...               ...         ...                 ...  ...
# 22518  NaN               NaN         NaN                 NaN  NaN
# 530    NaN               NaN           4                 NaN  NaN
# 4799   NaN               NaN         NaN                 NaN  NaN
# 22165  NaN               NaN           5                 NaN  NaN
# 10928  NaN               NaN         NaN                 NaN  NaN
#
#       Prothrombin time Platelet Count HCO3 (serum) Anion gap CK (CPK)  ...  \
# 28044              NaN        217.889           34   13.5556      267  ...
# 92195               13          167.2      26.3077   10.8462      NaN  ...
# 12987              NaN            NaN          NaN       NaN      NaN  ...
# 43632              NaN          256.5      19.7143   16.2857      NaN  ...
# 7105               NaN            NaN          NaN       NaN      NaN  ...
# ...                ...            ...          ...       ...      ...  ...
# 22518              NaN            NaN          NaN       NaN      NaN  ...
# 530                NaN            NaN          NaN       NaN      NaN  ...
# 4799               NaN            NaN          NaN       NaN      NaN  ...
# 22165              NaN            NaN          NaN       NaN      NaN  ...
# 10928              NaN            NaN          NaN       NaN      NaN  ...
#
#       Gentamicin (Trough) Intra Cranial Pressure HCO3 SVI Change  \
# 28044                 NaN                    NaN  NaN        NaN
# 92195                 NaN                    NaN  NaN        NaN
# 12987                 NaN                    NaN  NaN        NaN
# 43632                 NaN                    NaN  NaN        NaN
# 7105                  NaN                    NaN  NaN        NaN
# ...                   ...                    ...  ...        ...
# 22518                 NaN                    NaN  NaN        NaN
# 530                   NaN                    NaN  NaN        NaN
# 4799                  NaN                    NaN  NaN        NaN
# 22165                 NaN                    NaN  NaN        NaN
# 10928                 NaN                    NaN  NaN        NaN
#
#       Stroke Volume Index (SVI NICOM) CO / CI Change Cardiac Index (CI NICOM)  \
# 28044                             NaN            NaN                      NaN
# 92195                             NaN            NaN                      NaN
# 12987                             NaN            NaN                      NaN
# 43632                             NaN            NaN                      NaN
# 7105                              NaN            NaN                      NaN
# ...                               ...            ...                      ...
# 22518                             NaN            NaN                      NaN
# 530                               NaN            NaN                      NaN
# 4799                              NaN            NaN                      NaN
# 22165                             NaN            NaN                      NaN
# 10928                             NaN            NaN                      NaN
#
#       Stroke Volume Variation (SVV NICOM) Cardiac Output (CO NICOM)  \
# 28044                                 NaN                       NaN
# 92195                                 NaN                       NaN
# 12987                                 NaN                       NaN
# 43632                                 NaN                       NaN
# 7105                                  NaN                       NaN
# ...                                   ...                       ...
# 22518                                 NaN                       NaN
# 530                                   NaN                       NaN
# 4799                                  NaN                       NaN
# 22165                                 NaN                       NaN
# 10928                                 NaN                       NaN
#
#       Stroke Volume (SV NICOM)
# 28044                      NaN
# 92195                      NaN
# 12987                      NaN
# 43632                      NaN
# 7105                       NaN
# ...                        ...
# 22518                      NaN
# 530                        NaN
# 4799                       NaN
# 22165                      NaN
# 10928                      NaN
#
# [397 rows x 159 columns]

# %%
df_hf_s.isna().sum()
# Out:
# PTT                                    315
# Potassium (serum)                      302
# Phosphorous                            209
# Calcium non-ionized                    319
# INR                                    351
#                                       ...
# CO / CI Change                         396
# Cardiac Index (CI NICOM)               397
# Stroke Volume Variation (SVV NICOM)    396
# Cardiac Output (CO NICOM)              397
# Stroke Volume (SV NICOM)               396
# Length: 159, dtype: int64

# %%
max_number_of_nas = 500
df_hf_sys_2 = df_hf_s.loc[:, (df_hf_s.isnull().sum(axis=0) <= max_number_of_nas)]
df_hf_sys_2
# Out:
#        PTT Potassium (serum) Phosphorous Calcium non-ionized  INR  \
# 28044   61                 4           4                   9  NaN
# 92195  150           4.66667         NaN                   9    2
# 12987  NaN               NaN         NaN                 NaN  NaN
# 43632  NaN                 4           2                   8  NaN
# 7105   NaN               NaN         NaN                 NaN  NaN
# ...    ...               ...         ...                 ...  ...
# 22518  NaN               NaN         NaN                 NaN  NaN
# 530    NaN               NaN           4                 NaN  NaN
# 4799   NaN               NaN         NaN                 NaN  NaN
# 22165  NaN               NaN           5                 NaN  NaN
# 10928  NaN               NaN         NaN                 NaN  NaN
#
#       Prothrombin time Platelet Count HCO3 (serum) Anion gap CK (CPK)  ...  \
# 28044              NaN        217.889           34   13.5556      267  ...
# 92195               13          167.2      26.3077   10.8462      NaN  ...
# 12987              NaN            NaN          NaN       NaN      NaN  ...
# 43632              NaN          256.5      19.7143   16.2857      NaN  ...
# 7105               NaN            NaN          NaN       NaN      NaN  ...
# ...                ...            ...          ...       ...      ...  ...
# 22518              NaN            NaN          NaN       NaN      NaN  ...
# 530                NaN            NaN          NaN       NaN      NaN  ...
# 4799               NaN            NaN          NaN       NaN      NaN  ...
# 22165              NaN            NaN          NaN       NaN      NaN  ...
# 10928              NaN            NaN          NaN       NaN      NaN  ...
#
#       Gentamicin (Trough) Intra Cranial Pressure HCO3 SVI Change  \
# 28044                 NaN                    NaN  NaN        NaN
# 92195                 NaN                    NaN  NaN        NaN
# 12987                 NaN                    NaN  NaN        NaN
# 43632                 NaN                    NaN  NaN        NaN
# 7105                  NaN                    NaN  NaN        NaN
# ...                   ...                    ...  ...        ...
# 22518                 NaN                    NaN  NaN        NaN
# 530                   NaN                    NaN  NaN        NaN
# 4799                  NaN                    NaN  NaN        NaN
# 22165                 NaN                    NaN  NaN        NaN
# 10928                 NaN                    NaN  NaN        NaN
#
#       Stroke Volume Index (SVI NICOM) CO / CI Change Cardiac Index (CI NICOM)  \
# 28044                             NaN            NaN                      NaN
# 92195                             NaN            NaN                      NaN
# 12987                             NaN            NaN                      NaN
# 43632                             NaN            NaN                      NaN
# 7105                              NaN            NaN                      NaN
# ...                               ...            ...                      ...
# 22518                             NaN            NaN                      NaN
# 530                               NaN            NaN                      NaN
# 4799                              NaN            NaN                      NaN
# 22165                             NaN            NaN                      NaN
# 10928                             NaN            NaN                      NaN
#
#       Stroke Volume Variation (SVV NICOM) Cardiac Output (CO NICOM)  \
# 28044                                 NaN                       NaN
# 92195                                 NaN                       NaN
# 12987                                 NaN                       NaN
# 43632                                 NaN                       NaN
# 7105                                  NaN                       NaN
# ...                                   ...                       ...
# 22518                                 NaN                       NaN
# 530                                   NaN                       NaN
# 4799                                  NaN                       NaN
# 22165                                 NaN                       NaN
# 10928                                 NaN                       NaN
#
#       Stroke Volume (SV NICOM)
# 28044                      NaN
# 92195                      NaN
# 12987                      NaN
# 43632                      NaN
# 7105                       NaN
# ...                        ...
# 22518                      NaN
# 530                        NaN
# 4799                       NaN
# 22165                      NaN
# 10928                      NaN
#
# [397 rows x 159 columns]

# %%
max_number_of_nas = 35
df_hf_sys_3 = df_hf_sys_2.dropna(thresh=max_number_of_nas)
df_hf_sys_3
# Out:
#            PTT Potassium (serum) Phosphorous Calcium non-ionized      INR  \
# 28044       61                 4           4                   9      NaN
# 92195      150           4.66667         NaN                   9        2
# 18982  25.3333           4.28571     5.20833             7.85714  1.05263
# 31189      NaN               NaN           5                 NaN      NaN
# 87053      120               3.8     4.16667                   8        2
# ...        ...               ...         ...                 ...      ...
# 30845      NaN               NaN     4.71429                 NaN      NaN
# 17651      150               NaN         NaN                 NaN      NaN
# 30404      NaN               NaN         3.5                 NaN      NaN
# 530        NaN               NaN           4                 NaN      NaN
# 22165      NaN               NaN           5                 NaN      NaN
#
#       Prothrombin time Platelet Count HCO3 (serum) Anion gap CK (CPK)  ...  \
# 28044              NaN        217.889           34   13.5556      267  ...
# 92195               13          167.2      26.3077   10.8462      NaN  ...
# 18982               14        246.605      23.2391   15.3261  231.333  ...
# 31189              NaN          170.4           27        12      NaN  ...
# 87053             14.5        35.0488      19.4545   22.5882    405.9  ...
# ...                ...            ...          ...       ...      ...  ...
# 30845              NaN            NaN          NaN       NaN      NaN  ...
# 17651              NaN          152.2        28.25      11.5   224.25  ...
# 30404              NaN            NaN          NaN       NaN      NaN  ...
# 530                NaN            NaN          NaN       NaN      NaN  ...
# 22165              NaN            NaN          NaN       NaN      NaN  ...
#
#       Gentamicin (Trough) Intra Cranial Pressure HCO3 SVI Change  \
# 28044                 NaN                    NaN  NaN        NaN
# 92195                 NaN                    NaN  NaN        NaN
# 18982                 NaN                    NaN  NaN        NaN
# 31189                 NaN                    NaN  NaN        NaN
# 87053                 NaN                    NaN  NaN        NaN
# ...                   ...                    ...  ...        ...
# 30845                 NaN                    NaN  NaN        NaN
# 17651                 NaN                    NaN  NaN        NaN
# 30404                 NaN                    NaN  NaN        NaN
# 530                   NaN                    NaN  NaN        NaN
# 22165                 NaN                    NaN  NaN        NaN
#
#       Stroke Volume Index (SVI NICOM) CO / CI Change Cardiac Index (CI NICOM)  \
# 28044                             NaN            NaN                      NaN
# 92195                             NaN            NaN                      NaN
# 18982                             NaN            NaN                      NaN
# 31189                             NaN            NaN                      NaN
# 87053                             NaN            NaN                      NaN
# ...                               ...            ...                      ...
# 30845                             NaN            NaN                      NaN
# 17651                             NaN            NaN                      NaN
# 30404                             NaN            NaN                      NaN
# 530                               NaN            NaN                      NaN
# 22165                             NaN            NaN                      NaN
#
#       Stroke Volume Variation (SVV NICOM) Cardiac Output (CO NICOM)  \
# 28044                                 NaN                       NaN
# 92195                                 NaN                       NaN
# 18982                                 NaN                       NaN
# 31189                                 NaN                       NaN
# 87053                                 NaN                       NaN
# ...                                   ...                       ...
# 30845                                 NaN                       NaN
# 17651                                 NaN                       NaN
# 30404                                 NaN                       NaN
# 530                                   NaN                       NaN
# 22165                                 NaN                       NaN
#
#       Stroke Volume (SV NICOM)
# 28044                      NaN
# 92195                      NaN
# 18982                      NaN
# 31189                      NaN
# 87053                      NaN
# ...                        ...
# 30845                      NaN
# 17651                      NaN
# 30404                      NaN
# 530                        NaN
# 22165                      NaN
#
# [130 rows x 159 columns]

# %% [markdown]
# #### Diastolic Heart Failure - Subsample Population
# Complementary to the obtained dataframe, a subsample population of patients with Diastolic Heart Failure is selected, and all selected physiological measurement data are analyzed in order to obtain a DataFrame to model the data.

# %%
query = \
"""
SELECT *
FROM chartevents c
INNER JOIN diagnoses_icd d ON c.subject_id = d.subject_id
INNER JOIN d_items d_i ON c.itemid = d_i.itemid
WHERE d.icd9_code = '42830' AND (d_i.category = 'Hemodynamics' OR d_i.category = 'ABG' OR d_i.category = 'Hematology' 
OR d_i.category = 'Chemistry' OR d_i.category = 'Fluids - Other (Not In Use)' OR d_i.category = 'Blood Products/Colloids' 
OR d_i.category = 'Labs' OR d_i.category = 'Cardiovascular (Pacer Data)' OR d_i.category = 'Tandem Heart' 
OR d_i.category = 'NICOM')
"""
df_hf_dias = pd.read_sql_query(query, con)
df_hf_dias
# Out:
#           row_id  subject_id  hadm_id  icustay_id  itemid           charttime  \
# 0        1939294       16560   109090    225372.0  227686 2113-02-01 09:31:00
# 1        1946362       16560   175933    269374.0  225664 2113-03-26 22:00:00
# 2        1941647       16560   109090    263449.0  225664 2113-02-10 18:00:00
# 3        1941640       16560   109090    263449.0  227442 2113-02-10 17:13:00
# 4        1941639       16560   109090    263449.0  225677 2113-02-10 17:13:00
# ...          ...         ...      ...         ...     ...                 ...
# 637411  33717503       98744   168288    239780.0  220074 2127-06-11 23:00:00
# 637412  33717496       98744   168288    239780.0  220074 2127-06-11 22:45:00
# 637413  33717490       98744   168288    239780.0  220074 2127-06-11 22:15:00
# 637414  33717483       98744   168288    239780.0  220074 2127-06-11 22:00:00
# 637415  33717477       98744   168288    239780.0  220074 2127-06-11 21:50:00
#
#                  storetime   cgid value  valuenum  ... row_id  itemid  \
# 0      2113-02-01 09:35:00  20889    88      88.0  ...  15021  227686
# 1      2113-03-26 22:13:00  19895   156     156.0  ...  14111  225664
# 2      2113-02-10 16:04:00  20622   194     194.0  ...  14111  225664
# 3      2113-02-10 18:25:00  20889   4.2       4.2  ...  14756  227442
# 4      2113-02-10 18:25:00  20889   3.2       3.2  ...  14119  225677
# ...                    ...    ...   ...       ...  ...    ...     ...
# 637411 2127-06-11 23:14:00  18522    10      10.0  ...  12729  220074
# 637412 2127-06-11 22:54:00  18522     8       8.0  ...  12729  220074
# 637413 2127-06-11 22:16:00  18522    11      11.0  ...  12729  220074
# 637414 2127-06-11 22:15:00  18522    10      10.0  ...  12729  220074
# 637415 2127-06-11 21:55:00  18522     9       9.0  ...  12729  220074
#
#                           label            abbreviation    dbsource  \
# 0        Central Venous O2% Sat  Central Venous O2% Sat  metavision
# 1          Glucose finger stick    Glucose finger stick  metavision
# 2          Glucose finger stick    Glucose finger stick  metavision
# 3             Potassium (serum)       Potassium (serum)  metavision
# 4                   Phosphorous             Phosphorous  metavision
# ...                         ...                     ...         ...
# 637411  Central Venous Pressure                     CVP  metavision
# 637412  Central Venous Pressure                     CVP  metavision
# 637413  Central Venous Pressure                     CVP  metavision
# 637414  Central Venous Pressure                     CVP  metavision
# 637415  Central Venous Pressure                     CVP  metavision
#
#             linksto      category  unitname        param_type conceptid
# 0       chartevents          Labs         %           Numeric      None
# 1       chartevents          Labs      None           Numeric      None
# 2       chartevents          Labs      None           Numeric      None
# 3       chartevents          Labs      None  Numeric with tag      None
# 4       chartevents          Labs      None           Numeric      None
# ...             ...           ...       ...               ...       ...
# 637411  chartevents  Hemodynamics      mmHg           Numeric      None
# 637412  chartevents  Hemodynamics      mmHg           Numeric      None
# 637413  chartevents  Hemodynamics      mmHg           Numeric      None
# 637414  chartevents  Hemodynamics      mmHg           Numeric      None
# 637415  chartevents  Hemodynamics      mmHg           Numeric      None
#
# [637416 rows x 30 columns]

# %%
df_hf_dias_col = df_hf_dias.T.drop_duplicates().T
df_hf_dias_1 = df_hf_dias_col[df_hf_dias_col['param_type'] != 'Text']
df_hf_dias_1
# Out:
#           row_id subject_id hadm_id icustay_id  itemid           charttime  \
# 0        1939294      16560  109090     225372  227686 2113-02-01 09:31:00
# 1        1946362      16560  175933     269374  225664 2113-03-26 22:00:00
# 2        1941647      16560  109090     263449  225664 2113-02-10 18:00:00
# 3        1941640      16560  109090     263449  227442 2113-02-10 17:13:00
# 4        1941639      16560  109090     263449  225677 2113-02-10 17:13:00
# ...          ...        ...     ...        ...     ...                 ...
# 637411  33717503      98744  168288     239780  220074 2127-06-11 23:00:00
# 637412  33717496      98744  168288     239780  220074 2127-06-11 22:45:00
# 637413  33717490      98744  168288     239780  220074 2127-06-11 22:15:00
# 637414  33717483      98744  168288     239780  220074 2127-06-11 22:00:00
# 637415  33717477      98744  168288     239780  220074 2127-06-11 21:50:00
#
#                  storetime   cgid value valuenum  ... icd9_code row_id  \
# 0      2113-02-01 09:35:00  20889    88       88  ...     42830  15021
# 1      2113-03-26 22:13:00  19895   156      156  ...     42830  14111
# 2      2113-02-10 16:04:00  20622   194      194  ...     42830  14111
# 3      2113-02-10 18:25:00  20889   4.2      4.2  ...     42830  14756
# 4      2113-02-10 18:25:00  20889   3.2      3.2  ...     42830  14119
# ...                    ...    ...   ...      ...  ...       ...    ...
# 637411 2127-06-11 23:14:00  18522    10       10  ...     42830  12729
# 637412 2127-06-11 22:54:00  18522     8        8  ...     42830  12729
# 637413 2127-06-11 22:16:00  18522    11       11  ...     42830  12729
# 637414 2127-06-11 22:15:00  18522    10       10  ...     42830  12729
# 637415 2127-06-11 21:55:00  18522     9        9  ...     42830  12729
#
#                           label            abbreviation    dbsource  \
# 0        Central Venous O2% Sat  Central Venous O2% Sat  metavision
# 1          Glucose finger stick    Glucose finger stick  metavision
# 2          Glucose finger stick    Glucose finger stick  metavision
# 3             Potassium (serum)       Potassium (serum)  metavision
# 4                   Phosphorous             Phosphorous  metavision
# ...                         ...                     ...         ...
# 637411  Central Venous Pressure                     CVP  metavision
# 637412  Central Venous Pressure                     CVP  metavision
# 637413  Central Venous Pressure                     CVP  metavision
# 637414  Central Venous Pressure                     CVP  metavision
# 637415  Central Venous Pressure                     CVP  metavision
#
#             linksto      category unitname        param_type conceptid
# 0       chartevents          Labs        %           Numeric      None
# 1       chartevents          Labs     None           Numeric      None
# 2       chartevents          Labs     None           Numeric      None
# 3       chartevents          Labs     None  Numeric with tag      None
# 4       chartevents          Labs     None           Numeric      None
# ...             ...           ...      ...               ...       ...
# 637411  chartevents  Hemodynamics     mmHg           Numeric      None
# 637412  chartevents  Hemodynamics     mmHg           Numeric      None
# 637413  chartevents  Hemodynamics     mmHg           Numeric      None
# 637414  chartevents  Hemodynamics     mmHg           Numeric      None
# 637415  chartevents  Hemodynamics     mmHg           Numeric      None
#
# [635950 rows x 28 columns]

# %%
df_hf_dias_1.isna().sum()
# Out:
# row_id               0
# subject_id           0
# hadm_id              0
# icustay_id         703
# itemid               0
# charttime            0
# storetime            0
# cgid                 0
# value             1303
# valuenum          3131
# valueuom        364155
# warning         454407
# error           454407
# resultstatus    181680
# stopped         181543
# row_id               0
# hadm_id              0
# seq_num              0
# icd9_code            0
# row_id               0
# label                0
# abbreviation    454407
# dbsource             0
# linksto              0
# category             0
# unitname        454407
# param_type      454407
# conceptid       635950
# dtype: int64

# %%
df_hf_dias_1['value'].values.astype(str)
df_hf_dias_1['value'] = np.where(np.char.isnumeric(df_hf_dias_1['value'].values.astype(str)), df_hf_dias_1['value'].values, 'NaN')
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
cols = df_hf_dias_1['label'].unique()
rows = df_hf_dias_1['subject_id'].unique()
df_mean, df_max, df_min, df_std, df_col, df_id = [], [], [], [], [], []
df_hf_d = pd.DataFrame(index=rows, columns=cols)

for ind in df_hf_d.index:
    df_dias = df_hf_dias_1[df_hf_dias_1['subject_id']==ind]
    for col in df_hf_d.columns:
        df_hf_d.loc[ind,col] = df_dias[df_dias['label']==col].value.astype('float64').mean()
        
df_hf_d
# Out:
#       Central Venous O2% Sat Glucose finger stick Potassium (serum)  \
# 16560                     88              178.712                 4
# 23734                     74              125.474           4.33333
# 1725                     NaN                  NaN               NaN
# 24223                    NaN                  NaN               NaN
# 3267                     NaN              143.931                 5
# ...                      ...                  ...               ...
# 21021                    NaN                  121                 5
# 18123                    NaN                  NaN               NaN
# 21632                    NaN                  NaN               NaN
# 13599                    NaN                  NaN                 4
# 98744                     63                  133                 5
#
#       Phosphorous PO2 (Mixed Venous) Ionized Calcium  INR    PTT  \
# 16560         2.5               62.4               1    1     31
# 23734         3.5                NaN               1  NaN   26.5
# 1725            4                NaN             NaN  NaN    NaN
# 24223         NaN                NaN             NaN  NaN    NaN
# 3267          5.4                NaN               1    2  96.75
# ...           ...                ...             ...  ...    ...
# 21021           3                NaN             NaN  NaN    NaN
# 18123     3.66667                NaN             NaN  NaN    NaN
# 21632     4.28571                NaN             NaN  NaN    NaN
# 13599         4.5                NaN             NaN  NaN     32
# 98744     6.33333                 43               1  NaN     30
#
#       Prothrombin time Platelet Count  ... Tobramycin (Trough)  \
# 16560            14.25        209.875  ...                 NaN
# 23734               18        209.062  ...                 NaN
# 1725               NaN            NaN  ...                 NaN
# 24223              NaN            NaN  ...                 NaN
# 3267                19        162.714  ...                 NaN
# ...                ...            ...  ...                 ...
# 21021              NaN            298  ...                 NaN
# 18123              NaN            NaN  ...                 NaN
# 21632              NaN            NaN  ...                 NaN
# 13599              NaN        342.067  ...                 NaN
# 98744          16.3333        153.321  ...                 NaN
#
#       Tobramycin (Peak) Total Peripheral Resistance Index (TPRI) (NICOM)  \
# 16560               NaN                                              NaN
# 23734               NaN                                              NaN
# 1725                NaN                                              NaN
# 24223               NaN                                              NaN
# 3267                NaN                                              NaN
# ...                 ...                                              ...
# 21021               NaN                                              NaN
# 18123               NaN                                              NaN
# 21632               NaN                                              NaN
# 13599               NaN                                              NaN
# 98744               NaN                                              NaN
#
#       Total Peripheral Resistance (TPR) (NICOM)  \
# 16560                                       NaN
# 23734                                       NaN
# 1725                                        NaN
# 24223                                       NaN
# 3267                                        NaN
# ...                                         ...
# 21021                                       NaN
# 18123                                       NaN
# 21632                                       NaN
# 13599                                       NaN
# 98744                                       NaN
#
#       Thoracic Fluid Content (TFC) (NICOM) SVI Change CO / CI Change  \
# 16560                                  NaN        NaN            NaN
# 23734                                  NaN        NaN            NaN
# 1725                                   NaN        NaN            NaN
# 24223                                  NaN        NaN            NaN
# 3267                                   NaN        NaN            NaN
# ...                                    ...        ...            ...
# 21021                                  NaN        NaN            NaN
# 18123                                  NaN        NaN            NaN
# 21632                                  NaN        NaN            NaN
# 13599                                  NaN        NaN            NaN
# 98744                                  NaN        NaN            NaN
#
#       Gentamicin (Peak) Intra Cranial Pressure Phenobarbital
# 16560               NaN                    NaN           NaN
# 23734               NaN                    NaN           NaN
# 1725                NaN                    NaN           NaN
# 24223               NaN                    NaN           NaN
# 3267                NaN                    NaN           NaN
# ...                 ...                    ...           ...
# 21021               NaN                    NaN           NaN
# 18123               NaN                    NaN           NaN
# 21632               NaN                    NaN           NaN
# 13599               NaN                    NaN           NaN
# 98744               NaN                    NaN           NaN
#
# [703 rows x 168 columns]

# %%
df_hf_d.isna().sum()
# Out:
# Central Venous O2% Sat    684
# Glucose finger stick      491
# Potassium (serum)         542
# Phosphorous               326
# PO2 (Mixed Venous)        663
#                          ...
# SVI Change                703
# CO / CI Change            703
# Gentamicin (Peak)         703
# Intra Cranial Pressure    702
# Phenobarbital             702
# Length: 168, dtype: int64

# %%
max_number_of_nas = 500
df_hf_dias_2 = df_hf_d.loc[:, (df_hf_d.isnull().sum(axis=0) <= max_number_of_nas)]
df_hf_dias_2
# Out:
#       Glucose finger stick Phosphorous Platelet Count HCO3 (serum) Anion gap  \
# 16560              178.712         2.5        209.875      29.4524   10.0714
# 23734              125.474         3.5        209.062      25.0588   13.2353
# 1725                   NaN           4            NaN          NaN       NaN
# 24223                  NaN         NaN            NaN          NaN       NaN
# 3267               143.931         5.4        162.714         20.1      20.6
# ...                    ...         ...            ...          ...       ...
# 21021                  121           3            298           24        11
# 18123                  NaN     3.66667            NaN          NaN       NaN
# 21632                  NaN     4.28571            NaN          NaN       NaN
# 13599                  NaN         4.5        342.067      21.4375   11.6875
# 98744                  133     6.33333        153.321      19.9429   17.5429
#
#            BUN Differential-Monos Differential-Lymphs Differential-Eos  \
# 16560  23.8333                  6                   5              1.2
# 23734  16.9412                  3                   5                0
# 1725       NaN                NaN                 NaN              NaN
# 24223      NaN                NaN                 NaN              NaN
# 3267   30.5789            6.66667                  15                0
# ...        ...                ...                 ...              ...
# 21021       22            8.66667             15.6667                0
# 18123      NaN                NaN                 NaN              NaN
# 21632      NaN                2.5                 8.5                0
# 13599  36.6875            3.55556             12.3333          6.16667
# 98744     59.4                  3             1.66667                1
#
#       Differential-Basos  ... Platelets Glucose (70-105) Arterial PaO2  \
# 16560                  0  ...   282.571            165.4          85.8
# 23734                  0  ...       236          142.333        106.75
# 1725                 NaN  ...     139.5          151.706       119.656
# 24223                NaN  ...    184.75              127       93.8333
# 3267                   0  ...   198.222          116.882           NaN
# ...                  ...  ...       ...              ...           ...
# 21021           0.333333  ...   355.143          122.583           NaN
# 18123                NaN  ...   355.868              119       103.365
# 21632                  0  ...   254.357          141.573       116.103
# 13599                  0  ...   275.913          157.333       107.377
# 98744                  0  ...       NaN              NaN           NaN
#
#       Arterial PaCO2 Arterial CO2(Calc) Fingerstick Glucose  \
# 16560           49.6                 30                 129
# 23734             56                 28                 NaN
# 1725              39            23.9062             134.269
# 24223          87.75            38.6667                 122
# 3267             NaN                NaN             125.973
# ...              ...                ...                 ...
# 21021            NaN                NaN             139.667
# 18123        46.0952            28.9683             132.023
# 21632        43.5981            26.1028             132.996
# 13599        39.4762            22.9623             160.703
# 98744            NaN                NaN                 NaN
#
#       Phosphorous(2.7-4.5) Magnesium (1.6-2.6) Differential-Polys  \
# 16560                  NaN                   2                 88
# 23734                    4                 NaN                NaN
# 1725                     4                 NaN                NaN
# 24223                  NaN                   2                NaN
# 3267                     4                   2                 70
# ...                    ...                 ...                ...
# 21021                    3                   2                 72
# 18123              3.66667                   2                 74
# 21632              4.28571                   2               77.5
# 13599              4.71429                   2               62.4
# 98744                  NaN                 NaN                NaN
#
#       Calcium (8.4-10.2)
# 16560                  8
# 23734                NaN
# 1725                 NaN
# 24223                  8
# 3267                   9
# ...                  ...
# 21021                  8
# 18123                  9
# 21632              8.125
# 13599            9.11111
# 98744                NaN
#
# [703 rows x 47 columns]

# %%
max_number_of_nas = 35
df_hf_dias_3 = df_hf_dias_2.dropna(thresh=max_number_of_nas)
df_hf_dias_3
# Out:
#       Glucose finger stick Phosphorous Platelet Count HCO3 (serum) Anion gap  \
# 16560              178.712         2.5        209.875      29.4524   10.0714
# 23734              125.474         3.5        209.062      25.0588   13.2353
# 3267               143.931         5.4        162.714         20.1      20.6
# 20815                  NaN     3.66667            NaN          NaN       NaN
# 18982              162.736     5.20833        246.605      23.2391   15.3261
# ...                    ...         ...            ...          ...       ...
# 20124              152.231         2.5         229.13      20.1379   20.9655
# 32522                  NaN     2.66667            NaN          NaN       NaN
# 21021                  121           3            298           24        11
# 21632                  NaN     4.28571            NaN          NaN       NaN
# 13599                  NaN         4.5        342.067      21.4375   11.6875
#
#            BUN Differential-Monos Differential-Lymphs Differential-Eos  \
# 16560  23.8333                  6                   5              1.2
# 23734  16.9412                  3                   5                0
# 3267   30.5789            6.66667                  15                0
# 20815      NaN            1.66667             1.33333                0
# 18982  64.8478                1.4                6.65                0
# ...        ...                ...                 ...              ...
# 20124    42.75                2.8                 5.2              0.8
# 32522      NaN                  6                  15                0
# 21021       22            8.66667             15.6667                0
# 21632      NaN                2.5                 8.5                0
# 13599  36.6875            3.55556             12.3333          6.16667
#
#       Differential-Basos  ... Platelets Glucose (70-105) Arterial PaO2  \
# 16560                  0  ...   282.571            165.4          85.8
# 23734                  0  ...       236          142.333        106.75
# 3267                   0  ...   198.222          116.882           NaN
# 20815                  0  ...   278.569          129.973       114.981
# 18982               0.05  ...   264.495          135.696       136.343
# ...                  ...  ...       ...              ...           ...
# 20124                  0  ...   278.837          108.379       94.9268
# 32522                  0  ...   136.235          118.756       106.837
# 21021           0.333333  ...   355.143          122.583           NaN
# 21632                  0  ...   254.357          141.573       116.103
# 13599                  0  ...   275.913          157.333       107.377
#
#       Arterial PaCO2 Arterial CO2(Calc) Fingerstick Glucose  \
# 16560           49.6                 30                 129
# 23734             56                 28                 NaN
# 3267             NaN                NaN             125.973
# 20815        42.7358            25.9528             122.936
# 18982        46.9214            27.3741             150.099
# ...              ...                ...                 ...
# 20124        45.7073            26.9756             121.728
# 32522        39.3953            22.1395             135.095
# 21021            NaN                NaN             139.667
# 21632        43.5981            26.1028             132.996
# 13599        39.4762            22.9623             160.703
#
#       Phosphorous(2.7-4.5) Magnesium (1.6-2.6) Differential-Polys  \
# 16560                  NaN                   2                 88
# 23734                    4                 NaN                NaN
# 3267                     4                   2                 70
# 20815              3.66667                   2            61.3333
# 18982               5.0625                   2              77.75
# ...                    ...                 ...                ...
# 20124                    3                   2               70.5
# 32522              2.66667                   2                 73
# 21021                    3                   2                 72
# 21632              4.28571                   2               77.5
# 13599              4.71429                   2               62.4
#
#       Calcium (8.4-10.2)
# 16560                  8
# 23734                NaN
# 3267                   9
# 20815               7.75
# 18982                  8
# ...                  ...
# 20124            7.66667
# 32522                 10
# 21021                  8
# 21632              8.125
# 13599            9.11111
#
# [146 rows x 47 columns]

# %% [markdown]
# #### Systolic and Diastolic Heart Failure - DataFrame preparation
# After processing and obtaining the dataframe for each subsample (Systolic and Diastolic Heart Failure), a unique DataFrame is created for modeling the data, experimenting if there is a model that can use the available data to separate patients with Systolic Heart Failure from patients with Diastolic Heart Failure.

# %%
hf_df = pd.merge(df_hf_sys_3, df_hf_dias_3)
hf_df
# Out:
#        PTT Potassium (serum) Phosphorous Calcium non-ionized      INR  \
# 0  25.3333           4.28571     5.20833             7.85714  1.05263
# 1      NaN               NaN         2.7                 NaN      NaN
# 2      NaN                 4     1.57143                   9      NaN
# 3      119               4.5         4.5                   9        2
# 4      NaN               NaN         4.2                 NaN        4
# 5      NaN               NaN        4.75                 NaN      NaN
# 6     67.8           4.05882     3.03704             8.05263  3.16667
# 7      NaN               NaN     5.72727                 NaN      NaN
#
#   Prothrombin time Platelet Count HCO3 (serum) Anion gap CK (CPK)  ...  \
# 0               14        246.605      23.2391   15.3261  231.333  ...
# 1              NaN            NaN          NaN       NaN      NaN  ...
# 2              NaN          260.5         13.8   14.6842      134  ...
# 3              NaN          265.4      24.9545   17.9318      607  ...
# 4              NaN            105         34.5        11    103.5  ...
# 5              NaN            NaN          NaN       NaN      NaN  ...
# 6          16.4286        35.6449      23.4968   14.6753  428.429  ...
# 7              NaN            NaN          NaN       NaN      NaN  ...
#
#   Gentamicin (Trough) Intra Cranial Pressure HCO3 SVI Change  \
# 0                 NaN                    NaN  NaN        NaN
# 1                 NaN                    NaN  NaN        NaN
# 2                 NaN                    NaN  NaN        NaN
# 3                 NaN                    NaN  NaN        NaN
# 4                 NaN                    NaN  NaN        NaN
# 5                 NaN                    NaN  NaN        NaN
# 6                 NaN                    NaN  NaN        NaN
# 7                 NaN                    NaN  NaN        NaN
#
#   Stroke Volume Index (SVI NICOM) CO / CI Change Cardiac Index (CI NICOM)  \
# 0                             NaN            NaN                      NaN
# 1                             NaN            NaN                      NaN
# 2                             NaN            NaN                      NaN
# 3                             NaN            NaN                      NaN
# 4                             NaN            NaN                      NaN
# 5                             NaN            NaN                      NaN
# 6                             NaN            NaN                      NaN
# 7                             NaN            NaN                      NaN
#
#   Stroke Volume Variation (SVV NICOM) Cardiac Output (CO NICOM)  \
# 0                                 NaN                       NaN
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                                 NaN                       NaN
# 4                                 NaN                       NaN
# 5                                 NaN                       NaN
# 6                                 NaN                       NaN
# 7                                 NaN                       NaN
#
#   Stroke Volume (SV NICOM)
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
# 6                      NaN
# 7                      NaN
#
# [8 rows x 159 columns]

# %%
df_hf_dias_3.loc[:, 'HF_diagnosis'] = 'Dias'
hf_df_1 = pd.concat([df_hf_sys_3, df_hf_dias_3], axis=1)
hf_df_1['HF_diagnosis'] = hf_df_1.loc[:, 'HF_diagnosis'].fillna(value='Sys')
hf_df_1
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\pandas\core\indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\PC\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#        PTT Potassium (serum) Phosphorous Calcium non-ionized  INR  \
# 68     NaN               NaN         NaN                 NaN  NaN
# 148    NaN               NaN         NaN                 NaN  NaN
# 305    NaN               NaN     3.66667                   9  NaN
# 353    NaN               NaN           4                 NaN  NaN
# 530    NaN               NaN           4                 NaN  NaN
# ...    ...               ...         ...                 ...  ...
# 87754   36                 4           3                   9  NaN
# 89008   35                 4         NaN                 NaN  NaN
# 90680  NaN                 4           2                   8  NaN
# 91603  NaN                 4         NaN                 NaN  NaN
# 92195  150           4.66667         NaN                   9    2
#
#       Prothrombin time Platelet Count HCO3 (serum) Anion gap CK (CPK)  ...  \
# 68                 NaN            NaN          NaN       NaN      NaN  ...
# 148                NaN            NaN          NaN       NaN      NaN  ...
# 305                NaN          329.5         25.5        17      NaN  ...
# 353                NaN            NaN          NaN       NaN      NaN  ...
# 530                NaN            NaN          NaN       NaN      NaN  ...
# ...                ...            ...          ...       ...      ...  ...
# 87754               17        106.692      28.1818   12.7273      NaN  ...
# 89008             17.5             97           26   10.3333      NaN  ...
# 90680              NaN            160      27.3333   12.5556      NaN  ...
# 91603              NaN        106.333      27.5714        10      NaN  ...
# 92195               13          167.2      26.3077   10.8462      NaN  ...
#
#       Glucose (70-105) Arterial PaO2 Arterial PaCO2 Arterial CO2(Calc)  \
# 68                 NaN           NaN            NaN                NaN
# 148            173.167       103.795        41.9744            27.6154
# 305                NaN           NaN            NaN                NaN
# 353                NaN           NaN            NaN                NaN
# 530                NaN           NaN            NaN                NaN
# ...                ...           ...            ...                ...
# 87754              NaN           NaN            NaN                NaN
# 89008              NaN           NaN            NaN                NaN
# 90680              NaN           NaN            NaN                NaN
# 91603              NaN           NaN            NaN                NaN
# 92195              NaN           NaN            NaN                NaN
#
#       Fingerstick Glucose Phosphorous(2.7-4.5) Magnesium (1.6-2.6)  \
# 68                    NaN                  NaN                 NaN
# 148               151.239                    3                   2
# 305                   NaN                  NaN                 NaN
# 353                   NaN                  NaN                 NaN
# 530                   NaN                  NaN                 NaN
# ...                   ...                  ...                 ...
# 87754                 NaN                  NaN                 NaN
# 89008                 NaN                  NaN                 NaN
# 90680                 NaN                  NaN                 NaN
# 91603                 NaN                  NaN                 NaN
# 92195                 NaN                  NaN                 NaN
#
#       Differential-Polys Calcium (8.4-10.2) HF_diagnosis
# 68                   NaN                NaN          Sys
# 148              70.7143            7.66667         Dias
# 305                  NaN                NaN          Sys
# 353                  NaN                NaN          Sys
# 530                  NaN                NaN          Sys
# ...                  ...                ...          ...
# 87754                NaN                NaN          Sys
# 89008                NaN                NaN          Sys
# 90680                NaN                NaN          Sys
# 91603                NaN                NaN          Sys
# 92195                NaN                NaN          Sys
#
# [268 rows x 207 columns]

# %%
# Save final DataFrame with all curated data from selected subsample
hf_df_1.to_pickle('HF_df.pkl')

# %% [markdown]
# ## Conclusions
# A fundamental step to analyze the MIMIC database in the context of Heart Failure patients is to know the related available data. Making use of the lab exams and physiological measurements done at the ICU, it could be interesting to determine if there is relevant information about Heart Failure patients and specific differences between Heart Failure subtypes. Heart Failure diagnosis is done by hemodynamic analysis of medical imaging and extracted parameters. Thus, the first measurements taken for the analysis are the ones indicated with the tag "Hemodynamics". A DataFrame of Systolic Failure patients is prepared but the limited number of patients with values forces to include other measurements such as arterial blood gas (ABG) data, hematology, chemistry, fluids, blood products/colloids, labs, cardiovascular, tandem heart and non-invasive cardiac output monitor (NICOM). Then, a subsample of patients with Systolic and Diastolic Failure is selected, prepared and cleaned to build a DataFrame, including a label with the correspondent diagnosis, for modeling the data, experimenting if there is a model that can use the available data to identify and differentiate patients with Systolic Heart Failure and with Diastolic Heart Failure. The DataFrame is saved as a pickle file to be used in Part 3: Data Modeling.
